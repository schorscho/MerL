# %%
import os
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline  

import data_preparation as mdp
from mercari_config import MercariConfig

# %%
data = pd.read_csv(filepath_or_buffer=os.path.join(MercariConfig.DATASETS_DIR, 'mercari_test.tsv'), sep='\t',
                            header=0)

# %%
data
# Out:
#         test_id                                      name  item_condition_id  \
# 0             0  Breast cancer "I fight like a girl" ring                  1
# 1             1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers                  1
# 2             2                                 Coach bag                  1
# 3             3                             Floral Kimono                  2
# 4             4                          Life after Death                  3
# 5             5  iPhone 6 Plus or 6s Plus Vodka pink case                  1
# 6             6        Vintage Cameo Pendant & Brooch Pin                  3
# 7             7    Rose Gold Stainless Steel Quartz Watch                  1
# 8             8                   Daisy Marc Jacobs 3.4oz                  3
# 9             9          Rose Brushes and Silicone Sponge                  1
# 10           10         BNWT Coach coated canvas wristlet                  1
# ...

# %%
data.to_csv(path_or_buf=os.path.join(MercariConfig.DATASETS_DIR, MercariConfig.TEST_SET_FILE), sep=',')

# %%
data = mdp.load_data(MercariConfig.TEST_SET_FILE, test=True)

# %%
data
# Out:
#          Unnamed: 0                                      name  \
# test_id
# 0                 0  Breast cancer "I fight like a girl" ring
# 1                 1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers
# 2                 2                                 Coach bag
# 3                 3                             Floral Kimono
# 4                 4                          Life after Death
# 5                 5  iPhone 6 Plus or 6s Plus Vodka pink case
# 6                 6        Vintage Cameo Pendant & Brooch Pin
# 7                 7    Rose Gold Stainless Steel Quartz Watch
# 8                 8                   Daisy Marc Jacobs 3.4oz
# 9                 9          Rose Brushes and Silicone Sponge
# 10               10         BNWT Coach coated canvas wristlet
# 11               11               "John Carpenters Halloween"
# 12               12               Tuff Jeans Cowgirl Tuff Co.
# 13               13                     Lululemon crop size 6
# ...
