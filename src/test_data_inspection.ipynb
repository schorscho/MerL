# %%
import os
import pandas as pd

import data_preparation as mdp
from data_preparation import MerLConfig
# Out:
# Using TensorFlow backend.

# %%
# %%time

data = mdp.load_data(MerLConfig.COMP_FILE, sep='\t')
# Out:
# CPU times: user 2.36 s, sys: 240 ms, total: 2.6 s
# Wall time: 2.59 s

# %%
data
# Out:
#                                              name  item_condition_id  \
# item_id
# 0        Breast cancer "I fight like a girl" ring                  1
# 1        25 pcs NEW 7.5"x12" Kraft Bubble Mailers                  1
# 2                                       Coach bag                  1
# 3                                   Floral Kimono                  2
# 4                                Life after Death                  3
# 5        iPhone 6 Plus or 6s Plus Vodka pink case                  1
# 6              Vintage Cameo Pendant & Brooch Pin                  3
# 7          Rose Gold Stainless Steel Quartz Watch                  1
# 8                         Daisy Marc Jacobs 3.4oz                  3
# 9                Rose Brushes and Silicone Sponge                  1
# 10              BNWT Coach coated canvas wristlet                  1
# 11                    "John Carpenters Halloween"                  2
# ...
