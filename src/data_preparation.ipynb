# %%
import pandas as pd
import numpy as np
import spacy
from ipywidgets import FloatProgress
from IPython.display import display

from mercari_config import MercariConfig

# fix random seed for reproducibility
np.random.seed(7)

nlp = spacy.load('en')

# %%
df = pd.read_csv(filepath_or_buffer=os.path.join(MercariConfig.DATASETS_DIR, MercariConfig.TRAINING_SET_DATA_FILE), 
                    header=0, sep='\t', index_col=['train_id'])
# Out:
# /Users/gopora/MyStuff/Dev/python-virtual-envs/pie36-tf13/lib/python3.6/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.shape
# Out:
# (1482535, 7)

# %%
df.count()
# Out:
# name                 1482535
# item_condition_id    1482535
# category_name        1476208
# brand_name            849853
# price                1482535
# shipping             1482535
# item_description     1482531
# dtype: int64

# %%
df['category_name'].fillna(value='___very_empty_category___', inplace=True)

# %%
assert(len(df[df.category_name.isnull()]) == 0)

# %%
df['brand_name'].fillna(value='___very_empty_brand___', inplace=True)

# %%
assert(len(df[df.brand_name.isnull()]) == 0)

# %%
df['item_description'].fillna(value='___very_empty_description___', inplace=True)

# %%
assert(len(df[df.item_description.isnull()]) == 0)

# %%
df = df['item_description'].head(10000)

# %%
corpus = pd.DataFrame(columns=['word', 'word_id', 'count'])
corpus = corpus.astype(dtype={'word': str, 'word_id': int, 'count': int})

corpus.set_index(['word'], inplace=True)

max_word_id = 0
fp = FloatProgress(min=0, max=len(df))

display(fp)

for desc in df:
    desc_doc = nlp(desc)
    
    for token in desc_doc:
        if not token.text in corpus.index:
            corpus.loc[token.text] = (max_word_id, 1)
            max_word_id += 1
        else:
            corpus.at[token.text, 'count'] += 1
    
    fp.value += 1
# Out:
# FloatProgress(value=0.0, max=10000.0)

# %%
df.count()
# Out:
# 1482531

# %%
corpus.sort_values(by='count')
# Out:
#             word_id  count
# word
# burning       11966      1
# muslin        15864      1
# Poshy         15861      1
# pic4          15859      1
# Fury          15856      1
# dupes         15855      1
# Posie         15854      1
# sleepsack     15865      1
# observed      15853      1
# Nightly       15850      1
# Applied       15849      1
# Should        15848      1
# Trigger       15845      1
# Plucked       15844      1
# Overly        15843      1
# Rejuvenate    15851      1
# giraffes      15866      1
# QUANTITY      15869      1
# prison        15871      1
# Magnolia      15891      1
# denting       15889      1
# Spoked        15888      1
# Parts         15887      1
# Mechanism     15886      1
# Dancing       15885      1
# 1/25          15882      1
# JUMPING       15880      1
# LOWRIDER      15879      1
# IMPALA        15878      1
# CHEVROLET     15877      1
# ...             ...    ...
# Size             98   1296
# No                0   1317
# ...

# %%
corpus
# Out:
# Empty DataFrame
# Columns: [word_id, count]
# Index: []

# %%
corpus.loc['test'] = (0, 1)

# %%
corpus.loc['test2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/MyStuff/Dev/python-virtual-envs/pie36-tf13/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# ~/MyStuff/Dev/python-virtual-envs/pie36-tf13/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [test2] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-161-e39c3d1259a7> in <module>()
# ----> 1 corpus.loc['test2']
#
# ...
