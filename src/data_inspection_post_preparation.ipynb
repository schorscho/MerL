# %%
import data_preparation as mdp
from data_preparation import MerLConfig
# Out:
# Using TensorFlow backend.

# %%
# %%time

train_data = mdp.load_data(MerLConfig.TRAIN_PREP_FILE, sep=',')
# Out:
# CPU times: user 828 ms, sys: 80 ms, total: 908 ms
# Wall time: 907 ms

# %%
categories = train_data.groupby('category_name').count()

# %%
brands = train_data.groupby('brand_name').count()

# %%
len(categories), len(brands)
# Out:
# (1114, 2872)

# %%
test_data = mdp.load_data(MerLConfig.TEST_PREP_FILE, sep=',')

# %%
test_data
# Out:
#                                              name  item_condition_id  \
# item_id
# 2                                  AVA-VIV Blouse                  1
# 10                                Smashbox primer                  2
# 12                             Black Skater dress                  2
# 14             HOLD for Dogs2016 Minnetonka boots                  3
# 20                Torrid Nautical Peplum Tube Top                  3
# 23                             Triple car charger                  1
# 25                          Air Jordan carmine 6s                  3
# 31                 New Lularoe OS leggings, stars                  1
# 36                                   Black bag 30                  3
# 49                 Younique 3d fiber lash mascara                  1
# 56                    New Josie Maran Divine Drip                  1
# 61         NWT Lularoe OS French bulldog leggings                  1
# ...

# %%
embed_matrix = mdp.load_embedding_matrix(MerLConfig.EM_NAME_FILE)
# Out:
# 2018-02-07 18:35:42,169 - MerL.data_preparation - INFO - Loading embedding matrix from mercari_em_name ...
# 2018-02-07 18:35:42,415 - MerL.data_preparation - INFO - Loading embedding matrix from mercari_em_name_WP07R00_DP04R00.csv done.

# %%
embed_matrix
# Out:
#                 0         1         2         3         4         5         6  \
# word_id
# 0        1.157174  0.278684  0.651350  1.464310  1.223843 -0.608528  0.632897
# 1       -0.555833  0.270146 -0.308071 -0.739510  0.002788  0.296831  0.063785
# 2        1.233886 -0.847157 -0.797384  0.645333 -0.734673  1.272835 -0.245473
# 3       -0.023014  1.124512 -0.458759 -0.511372 -0.042473 -0.406409  0.746612
# 4       -0.216851 -0.133245  0.729236  0.442999  0.433252 -1.020548  0.005272
# 5        0.833920  0.457630  0.594720  0.379840  1.190400  0.899280  0.382640
# 6        0.662000  0.584690 -0.258740 -0.743380 -0.613620  1.402600 -0.916660
# 7        0.378360 -0.063352  1.159700 -0.497300 -0.078718 -0.155080  0.629600
# 8       -0.364655 -0.697814  0.514752  0.250430 -1.118183  0.249908  0.545576
# 9       -0.493400 -0.134710 -0.266560  0.718440  0.348790 -0.363090 -1.113400
# 10       0.581760 -0.527940 -0.039009 -0.919460 -0.213100 -0.569370  0.234360
# ...
