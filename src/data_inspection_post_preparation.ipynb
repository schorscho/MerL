# %%
import data_preparation as mdp
from data_preparation import MercariConfig

# %%
# %%time

train_data = mdp.load_data(MercariConfig.TRAINING_SET_PREP_FILE, sep=',')
# Out:
# CPU times: user 1.44 s, sys: 88 ms, total: 1.53 s
# Wall time: 2.54 s

# %%
categories = train_data.groupby('category_id').count()

# %%
brands = train_data.groupby('brand_id').count()

# %%
categories.sort_index()
# Out:
#              name  item_condition_id  category_name  brand_name  price  \
# category_id
# 5             996                996            996         996    996
# 8             776                776            776         776    776
# 9              49                 49             49          49     49
# 10            135                135            135         135    135
# 11             21                 21             21          21     21
# 12            122                122            122         122    122
# 13            133                133            133         133    133
# 14            470                470            470         470    470
# 15             17                 17             17          17     17
# 16            329                329            329         329    329
# 17              5                  5              5           5      5
# 18             80                 80             80          80     80
# ...

# %%
brands
# Out:
#             name  item_condition_id  category_name  brand_name   price  \
# brand_id
# 6         101123             101123         101123      101123  101123
# 8              8                  8              8           8       8
# 9              1                  1              1           1       1
# 10             1                  1              1           1       1
# 11             3                  3              3           3       3
# 12             6                  6              6           6       6
# 13            12                 12             12          12      12
# 14             5                  5              5           5       5
# 15             2                  2              2           2       2
# 16            69                 69             69          69      69
# 17             3                  3              3           3       3
# 18            22                 22             22          22      22
# ...

# %%
brands[brands.name > 2]
# Out:
#             name  item_condition_id  category_name  brand_name   price  \
# brand_id
# 6         101123             101123         101123      101123  101123
# 8              8                  8              8           8       8
# 11             3                  3              3           3       3
# 12             6                  6              6           6       6
# 13            12                 12             12          12      12
# 14             5                  5              5           5       5
# 16            69                 69             69          69      69
# 17             3                  3              3           3       3
# 18            22                 22             22          22      22
# 19            10                 10             10          10      10
# 20             7                  7              7           7       7
# 21             3                  3              3           3       3
# ...

# %%
train_data
# Out:
#                                               name  item_condition_id  \
# item_id
# 7             Girls cheer and tumbling bundle of 7                  3
# 13                            Sharpener and eraser                  1
# 19                  Cream/ Beige Front Cross Shirt                  2
# 39                 Victoria secret 34 c corest top                  3
# 46             Metallic purple slime with sparkles                  1
# 50                          Michael Kors CrossBody                  2
# 51                Led kids shoes size 3 and size 9                  1
# 57                          Infantino Baby Carrier                  3
# 66                         Silver choker Italy 925                  3
# 82                                  Mascara Bundle                  2
# 91                   Goosebumps HorrorLand DS Game                  3
# 109           Rose Gold Necklace with Silver Studs                  2
# ...

# %%
val_data = mdp.load_data(MercariConfig.VALIDATION_SET_PREP_FILE, sep=',')

# %%
val_data
# Out:
#                                              name  item_condition_id  \
# item_id
# 64                        Patagonia Fleece Jacket                  3
# 73                     Toddler Vineyard Vines Hat                  3
# 124                       Miss me skinny jeans 26                  4
# 132                           MOTU Skeletor Dorbz                  1
# 157                  Opi polish Hold for Chi Thuy                  1
# 279               Sweet Sixteen picture frame New                  1
# 369             Size Small Southern Boutique Tank                  3
# 402                      Guess blue bandage dress                  1
# 528      Yu Darvish '16 Platinum Ice Card Rangers                  2
# 529        New Unisex Converse Women's 11/Men's 9                  1
# 601                      Chocolate Soleil Bronzer                  1
# 618              Michael Kors purple leather tote                  3
# ...

# %%
name_train = mdp.load_index_sequence(file_name=MercariConfig.TRAINING_NAME_INDEX_FILE, max_len=None)
# Out:
# 2018-01-30 09:31:05,571 - MerL.data_preparation - INFO - Loading index_sequence_data from mercari_train_name_index.csv ...
# 2018-01-30 09:31:06,061 - MerL.data_preparation - INFO - Loading index_sequence_data from mercari_train_name_index.csv done.

# %%
name_train
# Out:
#          0       1       2       3       4       5       6       7       8  \
# item_id
# 7        1   47950  136355  133934       2  135677  144932    6627       0
# 13       1  109369  133934  138684       0       0       0       0       0
# 19       1       2       0       0       0       0       0       0       0
# 39       1  125468  147972    4384  135807       2  150720       0       0
# 46       1   78311  146572  148722  152113  149075       0       0       0
# 50       1       2       0       0       0       0       0       0       0
# 51       1   66094  142173  148331  148527    3884  133934  148527    7219
# 57       1   54992       0       0       0       0       0       0       0
# 66       1  110284  136463   55617    7364       0       0       0       0
# 82       1   76632   25515       0       0       0       0       0       0
# 91       1   48822       2   35284   47085       0       0       0       0
# ...

# %%
id_train = mdp.load_index_sequence(file_name=MercariConfig.TRAINING_ITEM_DESC_INDEX_FILE, max_len=None)
# Out:
# 2018-01-30 09:32:05,344 - MerL.data_preparation - INFO - Loading index_sequence_data from mercari_train_item_desc_index.csv ...
# 2018-01-30 09:32:18,779 - MerL.data_preparation - INFO - Loading index_sequence_data from mercari_train_item_desc_index.csv done.

# %%
id_train
# Out:
#          0       1       2       3       4       5       6       7       8  \
# item_id
# 7        1  186636  207728  237416  222147  220308  161465  197818  230464
# 13       1  129710  201778  242916       0       0       0       0       0
# 19       1   82345    2932  203049  221212  197333       9   76445  212187
# 39       1  178353  229444   24885  196624       2  238033  183108  196360
# 46       1  170972  231356  212146       2    2932  240603  231861    2932
# 50       1       2  126927   45314       0       0       0       0       0
# 51       1  108417  230372  206572  213291    2932  229807  198919  211189
# 57       1   90058  199358       9  129710  232808  221212  235024  233967
# 66       1  156707   98659  191494   36745  126499  178947    2932  215273
# 82       1   28788  117197  111241   69874  147646  117873       0       0
# 91       1   89413  240191  199358    7133   44869  189296  196399  237791
# ...
