# %%
import os
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline  

import data_preparation as mdp
from data_preparation import MercariConfig
# Out:
# Using TensorFlow backend.

# %%
df = mdp.load_data(MercariConfig.TRAINING_SET_FILE, '\t')

# %%
len(df)
# Out:
# 1482535

# %%
df.count()
# Out:
# name                 1482535
# item_condition_id    1482535
# category_name        1476208
# brand_name            849853
# price                1482535
# shipping             1482535
# item_description     1482531
# dtype: int64

# %%
df[df.item_description.isnull()]
# Out:
#                             name  item_condition_id  \
# item_id
# 511535        Shoes for Michelle                  4
# 861230                  Lipgloss                  4
# 1224924  Disney Minnie Head band                  3
# 1264242               For Bianca                  3
#
#                                       category_name brand_name  price  \
# item_id
# 511535                    Kids/Girls 0-24 Mos/Shoes        NaN    9.0
# 861230                           Beauty/Makeup/Lips        NaN   49.0
# 1224924  Women/Women's Accessories/Hair Accessories     Disney    9.0
# 1264242   Women/Women's Accessories/Scarves & Wraps        NaN   10.0
#
#          shipping item_description
# item_id
# 511535          0              NaN
# 861230          0              NaN
# 1224924         0              NaN
# 1264242         1              NaN

# %%
df.head()
# Out:
#                                         name  item_condition_id  \
# item_id
# 0        MLB Cincinnati Reds T Shirt Size XL                  3
# 1           Razer BlackWidow Chroma Keyboard                  3
# 2                             AVA-VIV Blouse                  1
# 3                      Leather Horse Statues                  1
# 4                       24K GOLD plated rose                  1
#
#                                              category_name brand_name  price  \
# item_id
# 0                                        Men/Tops/T-shirts        NaN   10.0
# 1        Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                              Women/Tops & Blouses/Blouse     Target   10.0
# 3                       Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                                  Women/Jewelry/Necklaces        NaN   44.0
#
#          shipping                                   item_description
# item_id
# ...

# %%
df.price.hist(bins=10)

# %%
df[df.price==0]
# Out:
#                                              name  item_condition_id  \
# item_id
# 1325         Alabama Crimson Tide Quality Lanyard                  1
# 2544                                Levi leggings                  3
# 2712                 Simple Red Lace Lingerie Top                  3
# 3576             Turquoise 15 Pc Makeup Brush Set                  1
# 3761                               Girls size 7/8                  3
# 5237                                  Nursing Bra                  3
# 6175        Multi Listing Bundled Package, Thanks                  2
# 7116         Nike Dri-Fit High Power Speed Tights                  1
# 7622                          Hands free earpiece                  1
# 10812                          Vampire candy bowl                  1
# 12738       Beautiful Janie and Jack loafers sz 4                  2
# 17617                     Coca Cola Stuffed Bears                  3
# ...

# %%
len(df.groupby("category_name").count())
# Out:
# 1287

# %%
df.groupby("brand_name").count()
# Out:
#                        name  item_condition_id  category_name  price  \
# brand_name
# !iT Jeans                 1                  1              1      1
# % Pure                   61                 61             61     61
# 10.Deep                   3                  3              3      3
# 191 Unlimited             1                  1              1      1
# 1byone                    1                  1              1      1
# 21men                     6                  6              6      6
# 24/7 Comfort Apparel      2                  2              2      2
# 2K Games                  1                  1              1      1
# 2XU                       2                  2              2      2
# 3.1 Phillip Lim          21                 21             21     21
# 3M®                      25                 25             25     25
# 47                        1                  1              1      1
# ...

# %%
len(df.groupby("name").count())
# Out:
# 1225273

# %%
df[['name']]
# Out:
#                                             name
# item_id
# 0            MLB Cincinnati Reds T Shirt Size XL
# 1               Razer BlackWidow Chroma Keyboard
# 2                                 AVA-VIV Blouse
# 3                          Leather Horse Statues
# 4                           24K GOLD plated rose
# 5               Bundled items requested for Ruie
# 6             Acacia pacific tides santorini top
# 7           Girls cheer and tumbling bundle of 7
# 8                          Girls Nike Pro shorts
# 9         Porcelain clown doll checker pants VTG
# 10                               Smashbox primer
# 11                        New vs pi k body mists
# 12                            Black Skater dress
# 13                          Sharpener and eraser
# 14            HOLD for Dogs2016 Minnetonka boots
# 15                   Sephora tarte birthday gift
# 16                             Glitter Eyeshadow
# 17           New: Baby K'tan active baby carrier
# ...

# %%
len(df.groupby("shipping").count())
# Out:
# 2

# %%
df.groupby("item_condition_id").count()
# Out:
#                      name  category_name  brand_name   price  shipping  \
# item_condition_id
# 1                  640549         638324      304571  640549    640549
# 2                  375479         373302      237099  375479    375479
# 3                  432161         430404      284444  432161    432161
# 4                   31962          31805       22042   31962     31962
# 5                    2384           2373        1697    2384      2384
#
#                    item_description
# item_condition_id
# 1                            640549
# 2                            375479
# 3                            432159
# 4                             31960
# 5                              2384

# %%
df['brand_name_up'] = df['brand_name'].str.upper()

# %%
len(df.groupby("brand_name_up").count())
# Out:
# 4809

# %%
df
# Out:
#                                             name  item_condition_id  \
# item_id
# 0            MLB Cincinnati Reds T Shirt Size XL                  3
# 1               Razer BlackWidow Chroma Keyboard                  3
# 2                                 AVA-VIV Blouse                  1
# 3                          Leather Horse Statues                  1
# 4                           24K GOLD plated rose                  1
# 5               Bundled items requested for Ruie                  3
# 6             Acacia pacific tides santorini top                  3
# 7           Girls cheer and tumbling bundle of 7                  3
# 8                          Girls Nike Pro shorts                  3
# 9         Porcelain clown doll checker pants VTG                  3
# 10                               Smashbox primer                  2
# 11                        New vs pi k body mists                  1
# 12                            Black Skater dress                  2
# ...
