# %%
import data_preparation as mdp
from data_preparation import MercariConfig
import numpy as np
import pandas as pd
import os

# %%
# %%time

df = mdp.load_data(MercariConfig.TRAINING_SET_PREP_FILE, sep=',')
# Out:
# CPU times: user 912 ms, sys: 96 ms, total: 1.01 s
# Wall time: 1.01 s

# %%
df
# Out:
#                                               name  item_condition_id  \
# item_id
# 7             Girls cheer and tumbling bundle of 7                  3
# 13                            Sharpener and eraser                  1
# 19                  Cream/ Beige Front Cross Shirt                  2
# 25                           Air Jordan carmine 6s                  3
# 39                 Victoria secret 34 c corest top                  3
# 46             Metallic purple slime with sparkles                  1
# 50                          Michael Kors CrossBody                  2
# 51                Led kids shoes size 3 and size 9                  1
# 57                          Infantino Baby Carrier                  3
# 64                         Patagonia Fleece Jacket                  3
# 66                         Silver choker Italy 925                  3
# 73                      Toddler Vineyard Vines Hat                  3
# ...

# %%
# %%time

df0 = pd.read_csv(filepath_or_buffer=os.path.join(MercariConfig.INPUT_DIR, MercariConfig.TRAINING_ITEM_DESC_INDEX_FILE), 
                  header=0, index_col=None)
# Out:
# CPU times: user 27.9 s, sys: 3.35 s, total: 31.2 s
# Wall time: 31.2 s

# %%
# %%time

df1 = pd.read_csv(filepath_or_buffer=os.path.join(MercariConfig.INPUT_DIR, MercariConfig.TRAINING_ITEM_DESC_INDEX_FILE), 
                  header=0, index_col=['item_id'])
# Out:
# /home/ubuntu/pie352-tf14/lib/python3.5/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# CPU times: user 30 s, sys: 3.24 s, total: 33.3 s
# Wall time: 33.3 s

# %%
# %%time

df2 = pd.read_csv(filepath_or_buffer=os.path.join(MercariConfig.INPUT_DIR, MercariConfig.TRAINING_ITEM_DESC_INDEX_FILE), 
                  header=0, index_col=['item_id', 'pos'])
# Out:
# /home/ubuntu/pie352-tf14/lib/python3.5/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# CPU times: user 35.8 s, sys: 5.13 s, total: 41 s
# Wall time: 41 s

# %%
# %%time

df0 = df0.pivot(index='item_id', columns='pos', values='word_id')
# Out:
# CPU times: user 57.8 s, sys: 12.4 s, total: 1min 10s
# Wall time: 1min 10s

# %%
# %%time

df0.to_csv(path_or_buf=os.path.join(MercariConfig.OUTPUT_DIR, 'scheisse.csv'))
# Out:
# CPU times: user 1min 8s, sys: 2.45 s, total: 1min 10s
# Wall time: 1min 10s

# %%
# %%time

df0 = pd.read_csv(filepath_or_buffer=os.path.join(MercariConfig.INPUT_DIR, 'scheisse.csv'), 
                  header=0, index_col=['item_id'])
# Out:
# CPU times: user 12.3 s, sys: 516 ms, total: 12.8 s
# Wall time: 12.8 s

# %%
df0.sort_index()
# Out:
#          0       1       2       3       4       5       6       7       8  \
# item_id
# 7        1  192588  212876  243731  228103  226344  166571  202874  236463
# 13       1  132799  206875  249355       0       0       0       0       0
# 19       1   82131    2968  208144  227173  202386       9   75537  218084
# 25       1  176454  197399   11725  198096    7037  176454  197399  199095
# 39       1  184200  235428   23618  201671       2  244343  188766  201392
# 46       1  176601  237367  218041       2    2968  246965  237872    2968
# 50       1  171774  109119   66389   51491  111601  129926   11742   43938
# 51       1  110212  236372  211715  219168    2968  235790  203984  217075
# 57       1   91140  204428       9  132799  238832  227173  241043  239996
# 64       1  121043    2900  191466   99129   90294   67533  123413  222322
# 66       1  162027  100713  196669   35132  129488  184645    2968  221151
# ...
